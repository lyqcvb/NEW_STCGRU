# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import DataLoader
import time
import joblib
import model as NN

# %%
seed = 34
total_fold = 10  # 10折
'''深度学习超参数'''
input_size = 16
hidden_size = 128
num_layers_lstm = 1
num_layers_bilstm = 2
num_classes = 2
batch_size = 64
num_epochs = 5
# learning_rate = 0.0003
learning_rate = 0.001

# model_name = 'dl.STCGRU()'
start = time.perf_counter()
name = locals()
NN.seed_everything(seed)
srate = 250
writer = SummaryWriter('./runs/' +'250hz_'+ str(seed))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def ensure_dir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

for i in range(total_fold):
    train_data_combine = torch.load("EEGData/250hz/TrainData/train_data_"
                                    + str(i + 1) + "_fold_with_seed_" + str(seed) + ".pth",weights_only=False)
    valid_data_combine = torch.load("EEGData/250hz/ValidData/valid_data_"
                                    + str(i + 1) + "_fold_with_seed_" + str(seed) + ".pth",weights_only=False)
    '''定义深度学习模型'''
    model = NN.STCGRU().to(device)
    '''定义损失函数Loss 和 优化算法optimizer'''
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0.05)
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20, eta_min=0.000001)  # 余弦退火
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.8)
    print('开始第%d次训练，共%d次' % (i + 1, total_fold))

    # 生成迭代器，根据小批量数据大小划分每批送入模型的数据集
    train_loader = DataLoader(dataset=train_data_combine,
                            batch_size=batch_size,
                            shuffle=True,
                            drop_last=True,
                            pin_memory=True,
                            num_workers=8)
    valid_loader = DataLoader(dataset=valid_data_combine,
                            batch_size=batch_size,
                            shuffle=True,
                            drop_last=True,
                            pin_memory=True,
                            num_workers=8)
    total_step = len(train_loader)
    '''模型训练'''
    for epoch in range(num_epochs):
        '''训练'''
        model, optimizer = NN.model_training(writer, i, type='train', num_epochs=num_epochs,
                                            epoch=epoch, loader=train_loader, neural_network=model,
                                            criterion=criterion, optimizer=optimizer)
        '''验证'''
        optimizer, lr_list = NN.model_training(writer, i, type='validation', epoch=epoch,
                                            loader=valid_loader, neural_network=model, criterion=criterion,
                                            optimizer=optimizer, scheduler=scheduler)
    ensure_dir("stcgru/250hz")
    torch.save(model.state_dict(),
            "stcgru/250hz/" +  str(i + 1) + "_fold_model_parameter_with_seed_" + str(seed) + ".pth")
    print("stcgru" + "模型第" + str(i + 1) + "次训练结果保存成功")
end = time.perf_counter()
print("训练及验证运行时间为", round(end - start), 'seconds')
# Out:
# 开始第1次训练，共10次
# Epoch: [  1/5] Train loss: 0.6258      Train accuracy: 0.6724
#                  Validation loss: 0.4849 Validation accuracy: 0.8313
# Epoch: [  2/5] Train loss: 0.4485      Train accuracy: 0.8794
#                  Validation loss: 0.4081 Validation accuracy: 0.9167
# Epoch: [  3/5] Train loss: 0.3867      Train accuracy: 0.9489
#                  Validation loss: 0.3861 Validation accuracy: 0.9448
# Epoch: [  4/5] Train loss: 0.3739      Train accuracy: 0.9616
#                  Validation loss: 0.3658 Validation accuracy: 0.9677
# Epoch: [  5/5] Train loss: 0.3594      Train accuracy: 0.9778
#                  Validation loss: 0.3704 Validation accuracy: 0.9615
# stcgru模型第1次训练结果保存成功
# 开始第2次训练，共10次
# Epoch: [  1/5] Train loss: 0.5714      Train accuracy: 0.7327
#                  Validation loss: 0.4323 Validation accuracy: 0.8896
# Epoch: [  2/5] Train loss: 0.4208      Train accuracy: 0.9041
#                  Validation loss: 0.4166 Validation accuracy: 0.9031
# Epoch: [  3/5] Train loss: 0.4168      Train accuracy: 0.9048
#                  Validation loss: 0.4108 Validation accuracy: 0.9198
# Epoch: [  4/5] Train loss: 0.4089      Train accuracy: 0.9136
#                  Validation loss: 0.3993 Validation accuracy: 0.9229
# Epoch: [  5/5] Train loss: 0.3783      Train accuracy: 0.9493
#                  Validation loss: 0.4067 Validation accuracy: 0.9198
# stcgru模型第2次训练结果保存成功
# 开始第3次训练，共10次
# Epoch: [  1/5] Train loss: 0.6430      Train accuracy: 0.6332
#                  Validation loss: 0.5526 Validation accuracy: 0.7885
# Epoch: [  2/5] Train loss: 0.5091      Train accuracy: 0.8144
#                  Validation loss: 0.4407 Validation accuracy: 0.8896
# Epoch: [  3/5] Train loss: 0.3892      Train accuracy: 0.9430
#                  Validation loss: 0.3715 Validation accuracy: 0.9615
# Epoch: [  4/5] Train loss: 0.3505      Train accuracy: 0.9808
#                  Validation loss: 0.3423 Validation accuracy: 0.9917
# Epoch: [  5/5] Train loss: 0.3442      Train accuracy: 0.9880
#                  Validation loss: 0.3427 Validation accuracy: 0.9844
# stcgru模型第3次训练结果保存成功
# 开始第4次训练，共10次
# Epoch: [  1/5] Train loss: 0.6180      Train accuracy: 0.6828
#                  Validation loss: 0.4285 Validation accuracy: 0.9115
# Epoch: [  2/5] Train loss: 0.3682      Train accuracy: 0.9641
#                  Validation loss: 0.3563 Validation accuracy: 0.9812
# Epoch: [  3/5] Train loss: 0.3464      Train accuracy: 0.9856
#                  Validation loss: 0.3422 Validation accuracy: 0.9896
# Epoch: [  4/5] Train loss: 0.3450      Train accuracy: 0.9891
#                  Validation loss: 0.3645 Validation accuracy: 0.9625
# Epoch: [  5/5] Train loss: 0.3439      Train accuracy: 0.9909
#                  Validation loss: 0.3442 Validation accuracy: 0.9927
# stcgru模型第4次训练结果保存成功
# 开始第5次训练，共10次
# Epoch: [  1/5] Train loss: 0.6013      Train accuracy: 0.6769
#                  Validation loss: 0.4031 Validation accuracy: 0.9396
# Epoch: [  2/5] Train loss: 0.3547      Train accuracy: 0.9823
#                  Validation loss: 0.3380 Validation accuracy: 0.9979
# Epoch: [  3/5] Train loss: 0.3399      Train accuracy: 0.9955
#                  Validation loss: 0.3405 Validation accuracy: 0.9958
# Epoch: [  4/5] Train loss: 0.3386      Train accuracy: 0.9970
#                  Validation loss: 0.3391 Validation accuracy: 0.9979
# Epoch: [  5/5] Train loss: 0.3364      Train accuracy: 0.9990
#                  Validation loss: 0.3365 Validation accuracy: 0.9990
# stcgru模型第5次训练结果保存成功
# 开始第6次训练，共10次
# Epoch: [  1/5] Train loss: 0.6507      Train accuracy: 0.6619
#                  Validation loss: 0.4646 Validation accuracy: 0.8698
# Epoch: [  2/5] Train loss: 0.4369      Train accuracy: 0.8864
#                  Validation loss: 0.4200 Validation accuracy: 0.8958
# Epoch: [  3/5] Train loss: 0.4141      Train accuracy: 0.9103
#                  Validation loss: 0.3829 Validation accuracy: 0.9458
# Epoch: [  4/5] Train loss: 0.3758      Train accuracy: 0.9567
#                  Validation loss: 0.3541 Validation accuracy: 0.9812
# Epoch: [  5/5] Train loss: 0.3583      Train accuracy: 0.9757
#                  Validation loss: 0.3522 Validation accuracy: 0.9823
# stcgru模型第6次训练结果保存成功
# 开始第7次训练，共10次
# Epoch: [  1/5] Train loss: 0.6296      Train accuracy: 0.6820
#                  Validation loss: 0.3699 Validation accuracy: 0.9802
# Epoch: [  2/5] Train loss: 0.3422      Train accuracy: 0.9928
#                  Validation loss: 0.3393 Validation accuracy: 0.9979
# Epoch: [  3/5] Train loss: 0.3351      Train accuracy: 0.9979
#                  Validation loss: 0.3334 Validation accuracy: 0.9979
# Epoch: [  4/5] Train loss: 0.3329      Train accuracy: 0.9991
#                  Validation loss: 0.3309 Validation accuracy: 0.9990
# Epoch: [  5/5] Train loss: 0.3339      Train accuracy: 0.9998
#                  Validation loss: 0.3336 Validation accuracy: 0.9990
# stcgru模型第7次训练结果保存成功
# 开始第8次训练，共10次
# Epoch: [  1/5] Train loss: 0.6863      Train accuracy: 0.5753
#                  Validation loss: 0.6281 Validation accuracy: 0.7250
# Epoch: [  2/5] Train loss: 0.5338      Train accuracy: 0.7889
#                  Validation loss: 0.4295 Validation accuracy: 0.9042
# Epoch: [  3/5] Train loss: 0.3973      Train accuracy: 0.9340
#                  Validation loss: 0.3562 Validation accuracy: 0.9792
# Epoch: [  4/5] Train loss: 0.3587      Train accuracy: 0.9763
#                  Validation loss: 0.3506 Validation accuracy: 0.9844
# Epoch: [  5/5] Train loss: 0.3494      Train accuracy: 0.9884
#                  Validation loss: 0.3403 Validation accuracy: 0.9958
# stcgru模型第8次训练结果保存成功
# 开始第9次训练，共10次
# Epoch: [  1/5] Train loss: 0.6733      Train accuracy: 0.5753
#                  Validation loss: 0.5439 Validation accuracy: 0.7896
# Epoch: [  2/5] Train loss: 0.4677      Train accuracy: 0.8442
#                  Validation loss: 0.4114 Validation accuracy: 0.9042
# Epoch: [  3/5] Train loss: 0.3883      Train accuracy: 0.9437
#                  Validation loss: 0.3768 Validation accuracy: 0.9510
# Epoch: [  4/5] Train loss: 0.3652      Train accuracy: 0.9707
#                  Validation loss: 0.3582 Validation accuracy: 0.9771
# Epoch: [  5/5] Train loss: 0.3565      Train accuracy: 0.9765
#                  Validation loss: 0.3764 Validation accuracy: 0.9521
# stcgru模型第9次训练结果保存成功
# 开始第10次训练，共10次
# Epoch: [  1/5] Train loss: 0.6888      Train accuracy: 0.5609
#                  Validation loss: 0.6741 Validation accuracy: 0.6365
# Epoch: [  2/5] Train loss: 0.5736      Train accuracy: 0.7413
#                  Validation loss: 0.5035 Validation accuracy: 0.8198
# Epoch: [  3/5] Train loss: 0.4794      Train accuracy: 0.8450
#                  Validation loss: 0.4620 Validation accuracy: 0.8594
# Epoch: [  4/5] Train loss: 0.4450      Train accuracy: 0.8822
#                  Validation loss: 0.4414 Validation accuracy: 0.8781
# Epoch: [  5/5] Train loss: 0.4366      Train accuracy: 0.8919
#                  Validation loss: 0.4257 Validation accuracy: 0.9031
# stcgru模型第10次训练结果保存成功
# 训练及验证运行时间为 133 seconds
